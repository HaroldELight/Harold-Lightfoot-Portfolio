# %%
pip install genai
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/831.8 kB ? eta -:--:--
#    ---------------------------------------- 831.8/831.8 kB 4.8 MB/s  0:00:00
# ...
# Failed to build tiktoken
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Building wheel for tiktoken (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [49 lines of output]
#       C:\Users\Harold\AppData\Local\Temp\pip-build-env-w620fa4j\overlay\Lib\site-packages\setuptools\config\_apply_pyprojecttoml.py:82: SetuptoolsDeprecationWarning: `project.license` as a TOML table is deprecated
#       !!
#
# ...
